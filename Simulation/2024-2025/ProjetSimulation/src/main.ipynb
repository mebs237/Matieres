# %%
from IPython.display import display , Markdown

# %%
from utils_main import *

# %%
from Generators import PythonGenerator, OurGenerator
from Tests import (Chi2Test , GapTest , KSTest  , MaximumTest , PokerTest , CouponCollectorTest)

# %%
from Analysing import ( analyse_sequence , evaluate_generator , compare_p_values , compare_summary_stats )

# %%
tes = [Chi2Test(), GapTest(), KSTest(), MaximumTest(), PokerTest(n_bins=6), CouponCollectorTest(d=6)]

# %%
ogen = OurGenerator(decimals=decimals)
pgen = PythonGenerator()

# %% [markdown]
# # Test des  fonctions

# %%
uniform_seq = np.random.uniform(0,1,1000)
non_uniform = np.random.normal(0,1,1000)

res_uniform = analyse_sequence(uniform_seq ,tests=tes , name='uniform_sequence')
res_non_uniform = analyse_sequence(non_uniform ,tests=tes , name='non_uniform_sequence')

res_uniform.save_all('Analyse')
res_non_uniform.save_all('Analyse')

# %%
display(Markdown(res_non_uniform.generate_report()))
# Out:
# # Rapport d'analyse : non_uniform_sequence
#
# ## Statistiques globales
#
# ```json
#
# {
#   "mean_p_value": 0.1101,
#   "median_p_value": 0.0,
#   "accept_ratio": 0.1667,
#   "rejection_ratio": 0.8333,
#   "std_p_value": 0.2477,
#   "alpha": 0.05
# }
# ```
#
# ## Interprétation des stats :
#
# - Conformité faible (p-value moyenne: 0.110)
# - Taux d'acceptation trop bas (16.7% vs 95.0% attendu)

# %%
display(Markdown(res_uniform.generate_report()))
# Out:
# # Rapport d'analyse : uniform_sequence
#
# ## Statistiques globales
#
# ```json
#
# {
#   "mean_p_value": 0.6628,
#   "median_p_value": 0.726,
#   "accept_ratio": 0.8333,
#   "rejection_ratio": 0.1667,
#   "std_p_value": 0.3656,
#   "alpha": 0.05
# }
# ```
#
# ## Interprétation des stats :
#
# - Bonne conformité (p-value moyenne: 0.663)
# - Taux d'acceptation trop bas (83.3% vs 95.0% attendu)

# %% [markdown]
# # Analyse des générateurs

# %%
res_ogen = evaluate_generator(ogen , tests=tes)
res_pgen = evaluate_generator(pgen,tests=tes)

# %%
res_ogen.hist_df
# Out:
#                                         Test  window_size  window_start  \
# 0                    Chi2_Test(nb_bins = 10)         1000             0
# 1                    Chi2_Test(nb_bins = 10)         1000          1000
# 2                    Chi2_Test(nb_bins = 10)         1000          2000
# 3                    Chi2_Test(nb_bins = 10)         1000          3000
# 4                    Chi2_Test(nb_bins = 10)         1000          4000
# ...                                      ...          ...           ...
# 19195  Coupon_Collector_Test (nb_coupon = 6)         3000          3000
# 19196  Coupon_Collector_Test (nb_coupon = 6)         3000          6000
# 19197  Coupon_Collector_Test (nb_coupon = 6)         5000             0
# 19198  Coupon_Collector_Test (nb_coupon = 6)         5000          5000
# 19199  Coupon_Collector_Test (nb_coupon = 6)        10000             0
#
#         p_value  accept   stat_obs  stat_crit  Iteration
# 0      0.554420    True   7.800000  16.918978          0
# 1      0.572847    True   7.620000  16.918978          0
# 2      0.875539    True   4.500000  16.918978          0
# 3      0.727851    True   6.120000  16.918978          0
# 4      0.662091    True   6.760000  16.918978          0
# ...         ...     ...        ...        ...        ...
# 19195  0.964595    True   8.781338  28.869299        199
# 19196  0.486746    True  17.533673  28.869299        199
# 19197  0.434664    True  20.375622  31.410433        199
# 19198  0.541246    True  18.702298  31.410433        199
# 19199  0.233677    True  27.540024  35.172462        199
#
# [19200 rows x 8 columns]

# %%
res_pgen.hist_df.head(10)
# Out:
#                       Test  window_size  window_start   p_value  accept  \
# 0  Chi2_Test(nb_bins = 10)         1000             0  0.827279    True
# 1  Chi2_Test(nb_bins = 10)         1000          1000  0.262249    True
# 2  Chi2_Test(nb_bins = 10)         1000          2000  0.848027    True
# 3  Chi2_Test(nb_bins = 10)         1000          3000  0.010310   False
# 4  Chi2_Test(nb_bins = 10)         1000          4000  0.757790    True
# 5  Chi2_Test(nb_bins = 10)         1000          5000  0.207730    True
# 6  Chi2_Test(nb_bins = 10)         1000          6000  0.231956    True
# 7  Chi2_Test(nb_bins = 10)         1000          7000  0.954930    True
# 8  Chi2_Test(nb_bins = 10)         1000          8000  0.796268    True
# 9  Chi2_Test(nb_bins = 10)         1000          9000  0.599693    True
#
#    stat_obs  stat_crit  Iteration
# 0      5.08  16.918978          0
# 1     11.20  16.918978          0
# 2      4.84  16.918978          0
# 3     21.58  16.918978          0
# 4      5.82  16.918978          0
# 5     12.10  16.918978          0
# 6     11.68  16.918978          0
# 7      3.22  16.918978          0
# 8      5.42  16.918978          0
# 9      7.36  16.918978          0

# %%
display(Markdown(res_ogen.generate_report()))
# Out:
# # Rapport d'analyse : OurGenerator1
#
# ## Statistiques globales
#
# ```json
#
# {
#   "mean_p_value": 0.4126,
#   "std_p_value": 0.3234,
#   "accept_ratio": 0.7869,
#   "rejection_ratio": 0.2131
# }
# ```
#
# ## Interprétation des stats :
#
# - Conformité modérée (p-value moyenne: 0.413)
# - Taux d'acceptation trop bas (78.7% vs 95.0% attendu)
# ## Analyse des granularités
# - Fenêtre de taille 1000 : 80.03% de conformité
# - Fenêtre de taille 3000 : 77.28% de conformité
# - Fenêtre de taille 5000 : 75.54% de conformité
# - Fenêtre de taille 10000 : 75.83% de conformité

# %%
res_ogen.plot_p_values_box_by_granularity()

# %%
compare_p_values(res_ogen , res_pgen)

# %% [markdown]
# #

# %%
res_ogen.plot_heatmap_acceptance()

# %%
res_ogen.plot_p_values_distribution()
