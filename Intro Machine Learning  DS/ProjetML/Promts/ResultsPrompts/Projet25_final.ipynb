# %% [markdown]
# # Projet Machine Learning – UMONS 2025
# ## Introduction
# Ce notebook présente l'ensemble du projet de prédiction du score de Macron aux élections 2022.

# %%
# Exemple de code
import pandas as pd
print('Chargement des données terminé.')
